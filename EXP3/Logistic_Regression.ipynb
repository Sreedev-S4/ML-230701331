# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# 1. Loading the Digits dataset (This provides the 0-9 rows you need)
digits = load_digits()
X = digits.data
y = digits.target

# 2. Splitting and Scaling
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# 3. Training the Logistic Regression model
# Removed 'multi_class' to fix the TypeError; max_iter=1000 ensures it finishes
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)

# 4. Making Predictions
y_pred = classifier.predict(X_test)

# 5. Formatted Output (Matches your handwritten record)
print(f"Logistic Regression Accuracy : {accuracy_score(y_test, y_pred):.2f}")
print("\nClassification Report :")
print(classification_report(y_test, y_pred))

# 6. Summary Metrics
report = classification_report(y_test, y_pred, output_dict=True)

print(f"Accuracy      {report['accuracy']:.2f}")
print(f"Macro avg     {report['macro avg']['f1-score']:.2f}")
print(f"Weighted avg  {report['weighted avg']['f1-score']:.2f}")
# Out:
# Logistic Regression Accuracy : 0.97
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       0.97      1.00      0.98        28
#            2       1.00      1.00      1.00        33
#            3       0.97      0.97      0.97        34
#            4       1.00      0.98      0.99        46
#            5       0.94      0.94      0.94        47
#            6       0.97      0.97      0.97        35
#            7       1.00      0.97      0.99        34
#            8       0.97      0.97      0.97        30
#            9       0.93      0.95      0.94        40
#
#     accuracy                           0.97       360
#    macro avg       0.97      0.97      0.97       360
# weighted avg       0.97      0.97      0.97       360
#
# Accuracy      0.97
# Macro avg     0.97
# Weighted avg  0.97
