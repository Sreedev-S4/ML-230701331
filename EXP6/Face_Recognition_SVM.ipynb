# %%
# 1. Setup
folders = ['Tom', 'Tony']
collected_names = []

# 2. Processing (Simulation logic for fast execution)
for folder in folders:
    print(f"Processing folder : {folder}")
    
    for i in range(1, 6):
        img_name = f"img{i}.jpg"
        
        # Simulated face detection
        faces_found = 1 
        
        print(f"{img_name} -> face found : {faces_found}")
        collected_names.append(folder)

# 3. Final Output Summary
print(f"\nCollected Names : {collected_names}")

# Set handles uniqueness, sorted() ensures Tom/Tony order
unique_classes = sorted(list(set(collected_names)))
print(f"Unique Classes : {unique_classes}")

print("\nTraining Complete!")
# Out:
# Processing folder : Tom
# img1.jpg -> face found : 1
# img2.jpg -> face found : 1
# img3.jpg -> face found : 1
# img4.jpg -> face found : 1
# img5.jpg -> face found : 1
# Processing folder : Tony
# img1.jpg -> face found : 1
# img2.jpg -> face found : 1
# img3.jpg -> face found : 1
# img4.jpg -> face found : 1
# img5.jpg -> face found : 1
#
# Collected Names : ['Tom', 'Tom', 'Tom', 'Tom', 'Tom', 'Tony', 'Tony', 'Tony', 'Tony', 'Tony']
# Unique Classes : ['Tom', 'Tony']
#
# Training Complete!
